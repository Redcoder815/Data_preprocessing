# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/Data_preprocessing/blob/main/oneHotBinning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipdb

# %%
import pandas as pd

data = {'color': ['Red', 'Blue', 'Green', 'Blue']}

df = pd.DataFrame(data)
# df.head()
one_hot_encoding = pd.get_dummies(df, columns = ['color'], prefix = 'color')
# print(one_hot_encoding)

data = {'Age': [23, 45, 18, 34, 67, 50, 21]}
df = pd.DataFrame(data)

bins = [0, 20, 40, 60, 100]
labels = ['0-20', '21-40', '41-60', '61+']

df['Age_Group'] = pd.cut(df['Age'], bins = bins, labels = labels, right = False)
# print(df)
