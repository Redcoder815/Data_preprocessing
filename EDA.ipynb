# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/Data_preprocessing/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipdb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

df = pd.read_csv('/content/WineQT.csv')
print(df.head())

df.shape
# df.info()

# df.columns.tolist()

# df.isnull().sum()
# df.nunique()
# ipdb.set_trace()
quality_count = df['quality'].value_counts()
# print(quality_count.index)

# plt.figure(figsize=(8, 6))
# plt.bar(quality_count.index, quality_count, color='Green')
# plt.title('Count plot of quality')
# plt.xlabel('Quality')
# plt.ylabel('Count')
# plt.show()

sns.set_style('darkgrid')
numerical_columns = df.select_dtypes(include=['int64','float64']).columns
print(numerical_columns)

plt.figure(figsize=(14, len(numerical_columns) * 3))

for idx, feature in enumerate(numerical_columns, 1):
  # ipdb.set_trace()
  plt.subplot(len(numerical_columns), 2, idx)
  sns.histplot(df[feature], kde=True)
  plt.title(f"{feature} | Skewness: {round(df[feature].skew(), 2)}")

plt.tight_layout()
plt.show()

df['quality'] = df['quality'].astype(str)
print("data type of quality")
print(df['quality'].dtypes)

plt.figure(figsize=(15, 10))

sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)

plt.title('Correlation Heatmap')
plt.show()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...
