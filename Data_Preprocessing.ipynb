# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/Data_preprocessing/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipdb

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/SampleFile.csv')

df = df.select_dtypes(include = np.number)

df.head()
# print(df)

max_abs = np.max(np.abs(df), axis = 0)

scaled_df = df / max_abs
scaled_df.head()

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)

scaled_df.head()

from sklearn.preprocessing import Normalizer
scaler = Normalizer()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data, columns = df.columns)
# scaled_df.head()
# print(scaled_df)

from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)
# scaled_df.head()
